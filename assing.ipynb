# %%
# Ans 1
 
Flask is a micro web framework written in framework.

Advantage of flask framework
(1)it is suitable for small projects.
(2)support for secure cookies.
(3)it is a lightweight framework that offer hastel free devlopment.

# %%
#Ans 2


from flask import Flask

app = Flask(__name__)

@app.route("/")

def Hello_World():
    return "<h> Hello World !! </h>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.36:5000
# Press CTRL+C to quit
# 172.18.0.2 - - [10/Apr/2023 10:10:19] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![hw.jpg](attachment:5bf7aa22-d15a-4421-aa04-4ed166c116dd.jpg)

# %%
#Ans 3
App routing is used to scale map the specific url with the associated function that is intended to perform some task.

It is used to acess some particular page like flask tutorial in web application.

# %%
# Ans 4 
from flask import Flask 

app = Flask(__name__)

@app.route("/welcome")
def welcome():
    return "<h1> Welcome to ABC Corporation </h1>"

if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.36:5000
# Press CTRL+C to quit

# %% [markdown]
# ![abc.jpg](attachment:0314ce4e-e0a2-4d84-a015-ce8a3f9077ee.jpg)

# %%
#Ans 4 (2)
from flask import Flask 

app = Flask(__name__)

@app.route("/")
def company_details():
    return "<h1> Company_Details : ABC Corporation </h1>  <h2> Location : India </h2> <h3> contact_details : 999-999-9999 </h3>"
    

if __name__ == "__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.18.0.36:5000
# Press CTRL+C to quit

# %% [markdown]
# ![contaat.jpg](attachment:f196859a-8809-4134-8000-8dcc777d9330.jpg)

# %%
# Ans 5

url_for() function is used for url building.

# %%
# Ans 5
from flask import url_for, Flask
appFlask = Flask(__name__)
@appFlask.route('/home')
def home():
   return 'We are in Home Page!'
with appFlask.test_request_context():
    print(url_for('login'))
